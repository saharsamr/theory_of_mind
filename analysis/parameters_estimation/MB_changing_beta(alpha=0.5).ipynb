# %%
from analysis.correctness_checker.behavior_analysis.MB_agent.plot import pulled_MB_result

# %%
alpha = 0.5

# %%
beta = 1.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/genmod/bayes_mixed_glm.py:792: UserWarning: VB fitting did not converge
#   warnings.warn("VB fitting did not converge")

# %%
beta = 2.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 3.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 4.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 5.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 6.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 7.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 8.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)

# %%
beta = 9.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/genmod/bayes_mixed_glm.py:792: UserWarning: VB fitting did not converge
#   warnings.warn("VB fitting did not converge")

# %%
beta = 10.0
pulled_MB_result('analysis/correctness_checker/behavior_analysis/data/MB/', alpha, beta)
