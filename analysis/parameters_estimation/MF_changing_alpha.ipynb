# %%
from analysis.simulation_results.plot_pure_agents_results import plot_pulled_MF_result

# %%
beta = 5.0

# %%
alpha = 0.1
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                 MixedLM     Dependent Variable:     repeat
# No. Observations:      2623        Method:                 REML
# No. Groups:            30          Scale:                  0.2394
# Min. group size:       78          Log-Likelihood:         -1860.6426
# Max. group size:       103         Converged:              Yes
# Mean group size:       87.4
# ---------------------------------------------------------------------
#                             Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   0.440    0.020 21.884 0.000  0.400  0.479
# ...

# %%
alpha = 0.2
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2557        Method:                 REML
# No. Groups:             30          Scale:                  0.2163
# Min. group size:        75          Log-Likelihood:         -1690.3428
# Max. group size:        99          Converged:              Yes
# Mean group size:        85.2
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.378    0.021 18.124 0.000  0.337  0.419
# ...

# %%
alpha = 0.3
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2672        Method:                 REML
# No. Groups:             30          Scale:                  0.2023
# Min. group size:        75          Log-Likelihood:         -1666.7729
# Max. group size:        101         Converged:              Yes
# Mean group size:        89.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.398    0.018 21.743 0.000  0.362  0.434
# ...

# %%
alpha = 0.4
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2661        Method:                 REML
# No. Groups:             30          Scale:                  0.1918
# Min. group size:        78          Log-Likelihood:         -1589.0697
# Max. group size:        102         Converged:              Yes
# Mean group size:        88.7
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.377    0.018 20.947 0.000  0.342  0.413
# ...

# %%
alpha = 0.5
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2608        Method:                 REML
# No. Groups:             30          Scale:                  0.1770
# Min. group size:        76          Log-Likelihood:         -1461.5090
# Max. group size:        100         Converged:              Yes
# Mean group size:        86.9
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.337    0.019 17.420 0.000  0.299  0.375
# ...

# %%
alpha = 0.6
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2604        Method:                 REML
# No. Groups:             30          Scale:                  0.1639
# Min. group size:        76          Log-Likelihood:         -1352.1995
# Max. group size:        100         Converged:              Yes
# Mean group size:        86.8
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.314    0.017 18.704 0.000  0.281  0.347
# ...

# %%
alpha = 0.7
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2637        Method:                 REML
# No. Groups:             30          Scale:                  0.1611
# Min. group size:        78          Log-Likelihood:         -1356.2248
# Max. group size:        103         Converged:              Yes
# Mean group size:        87.9
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.320    0.019 16.906 0.000  0.283  0.357
# ...

# %%
alpha = 0.8
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2631        Method:                 REML
# No. Groups:             30          Scale:                  0.1600
# Min. group size:        76          Log-Likelihood:         -1335.9066
# Max. group size:        104         Converged:              Yes
# Mean group size:        87.7
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.320    0.017 18.778 0.000  0.287  0.354
# ...

# %%
alpha = 0.9
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2689        Method:                 REML
# No. Groups:             30          Scale:                  0.1567
# Min. group size:        76          Log-Likelihood:         -1340.9490
# Max. group size:        105         Converged:              Yes
# Mean group size:        89.6
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.286    0.017 16.605 0.000  0.252  0.320
# ...
