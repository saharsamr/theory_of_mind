# %%
from analysis.simulation_results.plot_pure_agents_results import plot_pulled_MF_result

# %%
alpha = 0.3

# %%
beta = 1.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                 MixedLM     Dependent Variable:     repeat
# No. Observations:      2587        Method:                 REML
# No. Groups:            30          Scale:                  0.2464
# Min. group size:       73          Log-Likelihood:         -1870.3757
# Max. group size:       100         Converged:              Yes
# Mean group size:       86.2
# ---------------------------------------------------------------------
#                             Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   0.437    0.021 21.151 0.000  0.396  0.477
# common_reward               0.066    0.028  2.376 0.018  0.012  0.121
# unique_reward               0.077    0.028  2.728 0.006  0.022  0.132
# common_reward:unique_reward 0.024    0.039  0.609 0.542 -0.053  0.101
# Group Var                   0.000    0.002
# =====================================================================

# %%
beta = 2.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2556        Method:                 REML
# No. Groups:             30          Scale:                  0.2383
# Min. group size:        76          Log-Likelihood:         -1803.8241
# Max. group size:        101         Converged:              Yes
# Mean group size:        85.2
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.417    0.020 20.823 0.000  0.378  0.456
# common_reward                0.154    0.028  5.490 0.000  0.099  0.209
# unique_reward                0.161    0.027  5.844 0.000  0.107  0.214
# common_reward:unique_reward -0.059    0.039 -1.532 0.126 -0.135  0.017
# Group Var                    0.000    0.003
# ======================================================================

# %%
beta = 3.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2592        Method:                 REML
# No. Groups:             30          Scale:                  0.2219
# Min. group size:        74          Log-Likelihood:         -1738.4154
# Max. group size:        99          Converged:              Yes
# Mean group size:        86.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.390    0.020 19.706 0.000  0.352  0.429
# common_reward                0.209    0.027  7.637 0.000  0.155  0.262
# unique_reward                0.194    0.026  7.335 0.000  0.142  0.246
# common_reward:unique_reward -0.014    0.037 -0.368 0.713 -0.087  0.059
# Group Var                    0.000    0.002
# ======================================================================

# %%
beta = 4.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2611        Method:                 REML
# No. Groups:             30          Scale:                  0.2140
# Min. group size:        73          Log-Likelihood:         -1702.1173
# Max. group size:        97          Converged:              Yes
# Mean group size:        87.0
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.382    0.019 20.117 0.000  0.344  0.419
# common_reward                0.258    0.027  9.700 0.000  0.206  0.310
# unique_reward                0.247    0.026  9.664 0.000  0.197  0.298
# common_reward:unique_reward -0.083    0.036 -2.274 0.023 -0.154 -0.011
# Group Var                    0.000    0.002
# ======================================================================

# %%
beta = 5.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2672        Method:                 REML
# No. Groups:             30          Scale:                  0.2023
# Min. group size:        75          Log-Likelihood:         -1666.7729
# Max. group size:        101         Converged:              Yes
# Mean group size:        89.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.398    0.018 21.743 0.000  0.362  0.434
# common_reward                0.256    0.026  9.963 0.000  0.205  0.306
# unique_reward                0.260    0.025 10.581 0.000  0.212  0.309
# common_reward:unique_reward -0.056    0.035 -1.615 0.106 -0.125  0.012
# Group Var                    0.000    0.002
# ======================================================================

# %%
beta = 6.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2622        Method:                 REML
# No. Groups:             30          Scale:                  0.1887
# Min. group size:        78          Log-Likelihood:         -1550.4353
# Max. group size:        103         Converged:              Yes
# Mean group size:        87.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.347    0.019 18.565 0.000  0.311  0.384
# common_reward                0.381    0.025 15.414 0.000  0.333  0.430
# unique_reward                0.315    0.024 13.188 0.000  0.269  0.362
# common_reward:unique_reward -0.165    0.034 -4.849 0.000 -0.232 -0.099
# Group Var                    0.001    0.002
# ======================================================================

# %%
beta = 7.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2592        Method:                 REML
# No. Groups:             30          Scale:                  0.1956
# Min. group size:        74          Log-Likelihood:         -1576.1656
# Max. group size:        107         Converged:              Yes
# Mean group size:        86.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.369    0.019 19.904 0.000  0.333  0.406
# common_reward                0.325    0.026 12.691 0.000  0.275  0.375
# unique_reward                0.291    0.025 11.830 0.000  0.243  0.339
# common_reward:unique_reward -0.122    0.035 -3.492 0.000 -0.190 -0.053
# Group Var                    0.000    0.002
# ======================================================================

# %%
beta = 8.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2606        Method:                 REML
# No. Groups:             30          Scale:                  0.1782
# Min. group size:        63          Log-Likelihood:         -1462.9505
# Max. group size:        99          Converged:              Yes
# Mean group size:        86.9
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.371    0.018 20.627 0.000  0.336  0.407
# common_reward                0.345    0.025 13.845 0.000  0.296  0.394
# unique_reward                0.314    0.024 13.108 0.000  0.267  0.361
# common_reward:unique_reward -0.125    0.033 -3.759 0.000 -0.191 -0.060
# Group Var                    0.000    0.002
# ======================================================================

# %%
beta = 9.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2646        Method:                 REML
# No. Groups:             30          Scale:                  0.1741
# Min. group size:        72          Log-Likelihood:         -1454.6799
# Max. group size:        102         Converged:              Yes
# Mean group size:        88.2
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.382    0.017 22.732 0.000  0.349  0.415
# common_reward                0.392    0.024 16.465 0.000  0.345  0.438
# unique_reward                0.313    0.023 13.839 0.000  0.269  0.357
# common_reward:unique_reward -0.168    0.033 -5.154 0.000 -0.232 -0.104
# Group Var                    0.000    0.001
# ======================================================================

# %%
beta = 10.0
plot_pulled_MF_result('analysis/simulation_results/data/MF/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     repeat
# No. Observations:       2557        Method:                 REML
# No. Groups:             30          Scale:                  0.1812
# Min. group size:        76          Log-Likelihood:         -1463.5963
# Max. group size:        97          Converged:              Yes
# Mean group size:        85.2
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.406    0.019 21.136 0.000  0.368  0.443
# common_reward                0.306    0.025 12.181 0.000  0.256  0.355
# unique_reward                0.290    0.024 12.305 0.000  0.244  0.337
# common_reward:unique_reward -0.086    0.034 -2.527 0.012 -0.152 -0.019
# Group Var                    0.002    0.002
# ======================================================================
