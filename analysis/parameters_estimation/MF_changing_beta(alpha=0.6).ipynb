# %%
from analysis.correctness_checker.behavior_analysis.MF_agent.plot import pulled_MF_result

# %%
alpha = 0.6

# %%
beta = 1.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 2.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 3.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 4.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 5.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 6.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 7.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 8.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 9.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)

# %%
beta = 10.0
pulled_MF_result('analysis/correctness_checker/behavior_analysis/data/MF/', alpha, beta)
