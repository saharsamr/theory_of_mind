# %%
from analysis.simulation_re-Copy1sults.plot_pure_agents_results import plot_pulled_MB_result

# %%
alpha, beta = 0.1, 1.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.3, 1.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.6, 1.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.9, 1.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.1, 3.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.3, 3.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.6, 3.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.9, 3.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.1, 6.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.3, 6.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.6, 6.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:894: RuntimeWarning: invalid value encountered in true_divide
#   n_endog_mu = self._clean((1. - endog) / (1. - mu))
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/genmod/bayes_mixed_glm.py:792: UserWarning: VB fitting did not converge
#   warnings.warn("VB fitting did not converge")

# %%
alpha, beta = 0.9, 6.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.1, 9.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.3, 9.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.6, 9.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)

# %%
alpha, beta = 0.9, 9.0
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
