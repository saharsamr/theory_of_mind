# %%
from analysis.simulation_results.plot_pure_agents_results import plot_pulled_MB_result

# %%
beta = 5.0

# %%
alpha = 0.1
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2745        Method:                 REML
# No. Groups:           30          Scale:                  0.2364
# Min. group size:      76          Log-Likelihood:         -1924.6329
# Max. group size:      104         Converged:              Yes
# Mean group size:      91.5
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.308    0.036  8.451 0.000  0.237  0.380
# common_reward              0.257    0.054  4.719 0.000  0.150  0.364
# reward_prob                0.283    0.074  3.842 0.000  0.139  0.428
# common_reward:reward_prob -0.139    0.103 -1.345 0.179 -0.341  0.063
# Group Var                  0.000    0.001
# ====================================================================

# %%
alpha = 0.2
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2671        Method:                 REML
# No. Groups:           30          Scale:                  0.2212
# Min. group size:      75          Log-Likelihood:         -1783.7298
# Max. group size:      99          Converged:              Yes
# Mean group size:      89.0
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.210    0.036  5.792 0.000  0.139  0.280
# common_reward              0.367    0.053  6.976 0.000  0.264  0.470
# reward_prob                0.522    0.075  6.991 0.000  0.375  0.668
# common_reward:reward_prob -0.268    0.101 -2.642 0.008 -0.466 -0.069
# Group Var                  0.000    0.001
# ====================================================================

# %%
alpha = 0.3
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2749        Method:                 REML
# No. Groups:           30          Scale:                  0.2158
# Min. group size:      80          Log-Likelihood:         -1804.3733
# Max. group size:      106         Converged:              Yes
# Mean group size:      91.6
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.310    0.037  8.436 0.000  0.238  0.382
# common_reward              0.327    0.052  6.240 0.000  0.224  0.430
# reward_prob                0.268    0.073  3.676 0.000  0.125  0.410
# common_reward:reward_prob -0.080    0.098 -0.811 0.417 -0.272  0.113
# Group Var                  0.001    0.002
# ====================================================================

# %%
alpha = 0.4
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2736        Method:                 REML
# No. Groups:           30          Scale:                  0.2033
# Min. group size:      81          Log-Likelihood:         -1711.4305
# Max. group size:      104         Converged:              Yes
# Mean group size:      91.2
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.172    0.035  4.857 0.000  0.102  0.241
# common_reward              0.547    0.050 10.937 0.000  0.449  0.646
# reward_prob                0.507    0.070  7.221 0.000  0.369  0.644
# common_reward:reward_prob -0.403    0.095 -4.248 0.000 -0.589 -0.217
# Group Var                  0.000    0.002
# ====================================================================

# %%
alpha = 0.5
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2674        Method:                 REML
# No. Groups:           30          Scale:                  0.1931
# Min. group size:      75          Log-Likelihood:         -1603.8751
# Max. group size:      100         Converged:              Yes
# Mean group size:      89.1
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.303    0.035  8.751 0.000  0.235  0.371
# common_reward              0.485    0.050  9.612 0.000  0.386  0.584
# reward_prob                0.242    0.069  3.489 0.000  0.106  0.378
# common_reward:reward_prob -0.191    0.095 -1.999 0.046 -0.378 -0.004
# Group Var                  0.000    0.001
# ====================================================================

# %%
alpha = 0.6
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2745        Method:                 REML
# No. Groups:           30          Scale:                  0.1841
# Min. group size:      79          Log-Likelihood:         -1581.3882
# Max. group size:      107         Converged:              Yes
# Mean group size:      91.5
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.279    0.034  8.301 0.000  0.213  0.345
# common_reward              0.494    0.048 10.228 0.000  0.400  0.589
# reward_prob                0.216    0.067  3.229 0.001  0.085  0.347
# common_reward:reward_prob -0.108    0.091 -1.185 0.236 -0.287  0.071
# Group Var                  0.000    0.002
# ====================================================================

# %%
alpha = 0.7
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2642        Method:                 REML
# No. Groups:           30          Scale:                  0.1713
# Min. group size:      73          Log-Likelihood:         -1432.9949
# Max. group size:      100         Converged:              Yes
# Mean group size:      88.1
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.209    0.033  6.345 0.000  0.144  0.274
# common_reward              0.600    0.048 12.513 0.000  0.506  0.694
# reward_prob                0.353    0.066  5.352 0.000  0.223  0.482
# common_reward:reward_prob -0.254    0.091 -2.794 0.005 -0.432 -0.076
# Group Var                  0.001    0.002
# ====================================================================

# %%
alpha = 0.8
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2717        Method:                 REML
# No. Groups:           30          Scale:                  0.1747
# Min. group size:      74          Log-Likelihood:         -1493.8694
# Max. group size:      100         Converged:              Yes
# Mean group size:      90.6
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.235    0.032  7.363 0.000  0.173  0.298
# common_reward              0.622    0.047 13.102 0.000  0.529  0.715
# reward_prob                0.197    0.063  3.141 0.002  0.074  0.321
# common_reward:reward_prob -0.229    0.087 -2.613 0.009 -0.400 -0.057
# Group Var                  0.000    0.001
# ====================================================================

# %%
alpha = 0.9
plot_pulled_MB_result('analysis/simulation_results/data/MB/', alpha, beta)
# Out:
# /home/sahar/Documents/Theory of Mind/Codes/env/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                MixedLM     Dependent Variable:     repeat
# No. Observations:     2693        Method:                 REML
# No. Groups:           30          Scale:                  0.1771
# Min. group size:      76          Log-Likelihood:         -1508.4734
# Max. group size:      99          Converged:              Yes
# Mean group size:      89.8
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  0.270    0.033  8.118 0.000  0.205  0.335
# common_reward              0.517    0.048 10.793 0.000  0.423  0.611
# reward_prob                0.201    0.067  3.008 0.003  0.070  0.332
# common_reward:reward_prob -0.082    0.092 -0.895 0.371 -0.263  0.098
# Group Var                  0.002    0.002
# ====================================================================
